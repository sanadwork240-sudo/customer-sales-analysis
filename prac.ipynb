# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

data = {
    "name": ["sanad", "ashu", "abc"],
    "payrol": [25, 23, 32]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     name  payrol
# 0  sanad      25
# 1   ashu      23
# 2    abc      32
